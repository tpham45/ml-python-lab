# %% [markdown]
# # Lab Assignment Three: Extending Logistic Regression
# ## Date: 10/02/2025
# ## Team Members:
#
# | Member | Name                  |
# |--------|-----------------------|
# | 1      | Pham, Tuan Thanh     |
# | 2      | Lomelin, Nicko       |
# | 3      | Butcher, Karrie Zenobia |
#
# ### Data Using: xxxx
# # - Title of Topic we do on Lab 3
#
# ---

# %% [markdown]
# # Library Using

# %%
### Import library here

# %% [markdown]
# # I. Preparation and Overview

# %%
#Your code here

# %% [markdown]
# ---

# %% [markdown]
# # II. Modeling

# %%
#your code here

# %% [markdown]
# ---

# %% [markdown]
# # III. Deployment

# %%
# your code here & explanations of deployment process

# %% [markdown]
# ---

# %% [markdown]
# # IV. Exceptional Work

# %%
# your code here..
